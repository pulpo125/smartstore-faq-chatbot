# %% [markdown]
# ### ChromaDB 예제
# 1. Client 생성
# 2. Collection 초기화
#     - collection 이 없으면 생성 후 데이터 삽입
# 3. query (검색) 예제

# %%
# 1. Client 생성

from src.utils import get_chroma_db_client

client = get_chroma_db_client()
# Out:
# 2025-08-14 00:08:24,940 - chromadb.telemetry.product.posthog - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.

# %%
# 2. Collection 초기화

from src.db.chroma_db import get_or_create_collection
from src.config import cfg_engine

collection = get_or_create_collection(
    db_client=client, collection_name=cfg_engine.chroma_db.collection_name
)
# Out:
# 2025-08-14 00:08:24,965 - src.db.chroma_db - INFO - smartstore_faq이 존재합니다.

# %%
# 검색 예제
query_text = "스마트스토어 회원가입 방법"

# 검색
results = collection.query(
    query_texts=[query_text], n_results=5  # 검색 문장  # 상위 5개 결과
)

print(results["metadatas"][0][0])
# Out:
# 2025-08-14 00:08:26,173 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# {'answer': "('네이버 커머스 ID' 회원이 아닐 경우에는 로그인 화면에서 '회원가입하기' 누르고 신규 가입 후 권한을 부여받을 수 있습니다.) ※ 참고. 매니저별 권한변경/회수 가능 여부 · 통합 매니저: 계정 주매니저, 계정 부매니저의 권한을 회수하거나 변경할 수 있습니다. · 계정 주매니저: 계정 부매니저의 권한을 회수할 수 있습니다. · 계정 부매니저, 인플루언서, 대항사 : 매니저 관리 메뉴에 접근이 제한되므로 권한 변경 기능을 이용할 수 없습니다.! 주의. 판매자 계정에 접근해 판매자의 중요 정보를 관리, 확인할 수 있으므로 회원 초대 기능은 신중하게 사용해 주시고, 권한 부여/변경/회수로 인해 발생되는 모든 책임은 판매자 당사자에게 있습니다..", 'parent_id': 'd09d4c2e-7f09-4d5a-82d9-79ce136a6db7', 'document': "Qustion: 스마트스토어센터 권한 등록 방법\nAnswer: ('네이버 커머스 ID' 회원이 아닐 경우에는 로그인 화면에서 '회원가입하기' 누르고 신규 가입 후 권한을 부여받을 수 있습니다.) ※ 참고. 매니저별 권한변경/회수 가능 여부 · 통합 매니저: 계정 주매니저, 계정 부매니저의 권한을 회수하거나 변경할 수 있습니다. · 계정 주매니저: 계정 부매니저의 권한을 회수할 수 있습니다. · 계정 부매니저, 인플루언서, 대항사 : 매니저 관리 메뉴에 접근이 제한되므로 권한 변경 기능을 이용할 수 없습니다.! 주의. 판매자 계정에 접근해 판매자의 중요 정보를 관리, 확인할 수 있으므로 회원 초대 기능은 신중하게 사용해 주시고, 권한 부여/변경/회수로 인해 발생되는 모든 책임은 판매자 당사자에게 있습니다..", 'chunk_id': 1, 'question': '스마트스토어센터 권한 등록 방법'}
